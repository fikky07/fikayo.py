# %%
import random

class TicTac:
    def __init__(self):
        self.board = []
        
    def create_board(self):
        for i in range(3):
            row = []
            for j in range(3):
                row.append('-')
            self.board.append(row)
            
            
    def get_first_player(self):
        return random.randint(0,1)
    
    def spot(self,row,column,player):
        self.board[row][column] = player
        
    def player_win(self,player):
        win= none
        
        n = len(self.board)
        
    #rows
    for i in range(n):
        win = True
        for j in range(n):
            if self.board[i][j] != player:
                win = False
                break
                
        if win:
            return win
        
        
        
    #columns
    for i in range(n):
        win = True
        for j in range(n):
            if self.board[j][i] != player:
                win = False
                break
                
        if win:
            return win
        
        
    #diagonals
    win = True
    for i in range(n):
        if self.board[i][j] !=player:
            win= False
            break
            
    if win:
        return win
    return False

    for row in self.board:
        for item in row:
            if item =='-':
                return False
    return True
        
def is_board_filled(self):
    for row in self.board:
        for item in row:
            if  item =='-':
                return False
    return True

def swapplayer_turn(self,player):
    return 'x' if player =='O' else 'O'

def showboard(self):
    for row in self.board:
        for item in row:
            print(item, end=" ")
        print()
        
def start(self):
    self.create_board()
    
    player = 'X' if self.get_random_first_player() == 1 else 'O'
    while True:
        print(f"player{player}turn")
        
        self.show_board()
        
        #taking user input
        row,column = list(
            map(int, input("Enter row and column numbers to fix spot:").split()))
        
        #fixing spot
        self.fix_spot(row - 1, column -1,player)
        
        #checking if current player won or not
        if self.is_player_win(player):
            print(f"player{player}wins the game")
             break
                
        #checking if current player draw or not
        if self.is_board_filled():
            print("Draw Match")
            break
            
        #swapping the turn
        player = self.swap_player_turn(player)
            
            
        #showing the final view of the board
        print()
        self.show_board()
        
        
        
        
#starting game
tic_tac=TicTac()
tic_tac.start()
# Out:
#   Cell In[2], line 103
#     break
#     ^
# IndentationError: unexpected indent
